# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
# %matplotlib inline
# Out:
# /Users/perdue/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
f = h5py.File('minosmatch_muondat_me1Bmc_0000.hdf5', 'r')

# %%
for name in f:
    print name
    print np.shape(f[name])
# Out:
# eventids
# (24999,)
# muon_data
# (24999, 10)

# %%
muon_shp = np.shape(f['muon_data'])
print muon_shp
# Out:
# (24999, 10)

# %%
muond = np.zeros(muon_shp, dtype='f')

# %%
muond = f['muon_data'][:]

# %%
muond[0:5]
# Out:
# array([[  1.11472000e+02,  -6.81322021e+02,   8.27321973e+03,
#           1.11558998e+02,  -6.81455017e+02,   8.27321973e+03,
#           1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [ -7.58791016e+02,  -5.70343018e+02,   6.50929004e+03,
#          -7.58791016e+02,  -5.70343018e+02,   6.50929004e+03,
#           1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  3.98272003e+02,  -3.82514008e+02,   4.91225977e+03,
#           3.91225006e+02,  -3.87760010e+02,   5.00039990e+03,
#           2.00000000e+00,   1.00000000e+00,   1.46619999e+00,
#           0.00000000e+00],
#        [ -4.91151001e+02,   7.49689026e+02,   7.42975977e+03,
#          -4.92502991e+02,   7.49969971e+02,   7.43862012e+03,
#           2.00000000e+00,   1.00000000e+00,   4.79509020e+00,
#           0.00000000e+00],
#        [  6.75628967e+01,   3.06428986e+02,   4.48104980e+03,
# ...

# %%
# vtx_reco_x
n, bins, patches = plt.hist(muond[:,0])

# %%
# vtx_reco_y
n, bins, patches = plt.hist(muond[:,1])

# %%
# vtx_reco_z
n, bins, patches = plt.hist(muond[:,2])

# %%
# muon_orig_x
n, bins, patches = plt.hist(muond[:,3])

# %%
# muon_orig_y
n, bins, patches = plt.hist(muond[:,4])

# %%
# muon_orig_z
n, bins, patches = plt.hist(muond[:,5])

# %%
# vtx_n_tracks_prim
n, bins, patches = plt.hist(muond[:,6])

# %%
# vtx_fit_converged
n, bins, patches = plt.hist(muond[:,7])

# %%
# vtx_fit_chi2
n, bins, patches = plt.hist(muond[:,8])

# %%
# vtx_used_short_track
n, bins, patches = plt.hist(muond[:,9])
