# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/perdue/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
with np.load('models/lminervatriamese_beta1456937562_beta_v0r0.npz') as f:
    param_values = [f['arr_%d' % i] for i in range(len(f.files))]

# %%
len(param_values)
# Out:
# 20

# %%
layer_names = {0:'conv-x', 1:'bias-x', 2:'conv-x', 3:'bias-x', 4:'dense-x', 5:'bias-x',
               6:'conv-u', 7:'bias-u', 8:'conv-u', 9:'bias-u', 10:'dense-u', 11:'bias-u',
               12:'conv-v', 13:'bias-v', 14:'conv-v', 15:'bias-v', 16:'dense-v', 17:'bias-v',
               18:'across-dense1', 19:'accros-bias1'
              }

# %%
for i, p in enumerate(param_values):
    print "{:02d}, {:15s}, {}".format(i, layer_names[i], np.shape(p))
# Out:
# 00, conv-x         , (64, 1, 5, 5)
# 01, bias-x         , (64,)
# 02, conv-x         , (32, 64, 4, 4)
# 03, bias-x         , (32,)
# 04, dense-x        , (3200, 256)
# 05, bias-x         , (256,)
# 06, conv-u         , (64, 1, 5, 5)
# 07, bias-u         , (64,)
# 08, conv-u         , (32, 64, 4, 4)
# 09, bias-u         , (32,)
# 10, dense-u        , (3200, 256)
# 11, bias-u         , (256,)
# 12, conv-v         , (64, 1, 5, 5)
# 13, bias-v         , (64,)
# 14, conv-v         , (32, 64, 4, 4)
# 15, bias-v         , (32,)
# 16, dense-v        , (3200, 256)
# 17, bias-v         , (256,)
# 18, across-dense1  , (768, 11)
# 19, accros-bias1   , (11,)

# %%
# look at first x convolution
fig = plt.figure(figsize=(18, 60))
gs = plt.GridSpec(16, 4)
for i in range(0, 64):
    ax = plt.subplot(gs[i])
    ax.imshow(param_values[0][i][0], interpolation=None)
    
figname = 'first-x-conv-weights-64.pdf'
plt.savefig(figname)
