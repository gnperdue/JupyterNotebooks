# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
# %matplotlib inline

# %%
from evtid_utils import decode_eventid

# %%
f = h5py.File('../hdf5/minosmatch_nukecczdefs_genallzwitht_pcodecap66_127x50x25_xtxutuvtv_me1Amc.hdf5', 'r')

# %%
for name in f:
    print name
# Out:
# eventids
# hitimes-u
# hitimes-v
# hitimes-x
# planecodes
# segments
# zs

# %%
n, bins, patches = plt.hist(f['segments'][:], bins=10, range=(0, 11))

# %%
n
# Out:
# array([  392339.,   358751.,   292513.,   212663.,   275366.,   118770.,
#          124289.,   348296.,    30956.,  4507288.])

# %%
n / n[-1]
# Out:
# array([ 0.08704547,  0.07959354,  0.06489778,  0.04718203,  0.0610935 ,
#         0.02635066,  0.02757512,  0.07727396,  0.00686799,  1.        ])

# %%
n, bins, patches = plt.hist(f['planecodes'][:])

# %%
np.min(f['planecodes']), np.max(f['planecodes'])
# Out:
# (0, 66)

# %%
fig = plt.figure(figsize=(16,16))
_, _, _ = plt.hist(f['planecodes'][:], bins=67, range=(0, 66))
fig.savefig('eroica_me1Amc_planecodes_all.pdf', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(16,16))
_, _, _ = plt.hist(f['planecodes'][:], bins=66, range=(0, 65))
fig.savefig('eroica_me1Amc_planecodes.pdf', bbox_inches='tight')
